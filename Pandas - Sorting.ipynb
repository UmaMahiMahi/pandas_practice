# %% [markdown]
# ### Pandas - Sorting

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Functions

# %%
ins_df = pd.read_csv('medical_insurance.csv')
ins_df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
emp_df = pd.read_csv('Emp_data.csv')
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# ### 1. sort_index()

# %%
emp_df.sort_index(axis = 0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
array = np.random.randint(10,50,size = (6,5))
df = pd.DataFrame(array, columns=list("ABCDE"), index = list('python'))
df
# Out:
#     A   B   C   D   E
# p  14  39  37  16  41
# y  29  40  46  19  33
# t  18  28  42  31  37
# h  37  13  32  35  25
# o  46  24  26  14  44
# n  22  19  48  42  28

# %%
df2 = df.sort_index(axis = 0)
df2
# Out:
#     A   B   C   D   E
# h  37  13  32  35  25
# n  22  19  48  42  28
# o  46  24  26  14  44
# p  14  39  37  16  41
# t  18  28  42  31  37
# y  29  40  46  19  33

# %%
df2.to_csv('test.csv', index = True)

# %%
emp_df.sort_index(axis = 1)
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36        Denver  677509       Lois  168251
# 1             9.01       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0              60
# 1              60
# 2              68
# 3              51
# ...

# %%
ins_df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
ins_df.sort_index(axis = 1)
# Out:
#       age     bmi      charges  children  gender     region smoker
# 0      19  27.900  16884.92400         0  female  southwest    yes
# 1      18  33.770   1725.55230         1    male  southeast     no
# 2      28  33.000   4449.46200         3    male  southeast     no
# 3      33  22.705  21984.47061         0    male  northwest     no
# 4      32  28.880   3866.85520         0    male  northwest     no
# ...   ...     ...          ...       ...     ...        ...    ...
# 1333   50  30.970  10600.54830         3    male  northwest     no
# 1334   18  31.920   2205.98080         0  female  northeast     no
# 1335   18  36.850   1629.83350         0  female  southeast     no
# 1336   21  25.800   2007.94500         0  female  southwest     no
# 1337   61  29.070  29141.36030         0  female  northwest    yes
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### 2. sort_values()

# %%
ins_df['age'].sort_values()
# Out:
# 1248    18
# 482     18
# 492     18
# 525     18
# 529     18
#         ..
# 398     64
# 335     64
# 378     64
# 1265    64
# 635     64
# Name: age, Length: 1338, dtype: int64

# %%
ins_df.sort_values('age')
# Out:
#       age  gender     bmi  children smoker     region      charges
# 1248   18  female  39.820         0     no  southeast   1633.96180
# 482    18  female  31.350         0     no  southeast   1622.18850
# 492    18  female  25.080         0     no  northeast   2196.47320
# 525    18  female  33.880         0     no  southeast  11482.63485
# 529    18    male  25.460         0     no  northeast   1708.00140
# ...   ...     ...     ...       ...    ...        ...          ...
# 398    64    male  25.600         2     no  southwest  14988.43200
# 335    64    male  34.500         0     no  southwest  13822.80300
# 378    64  female  30.115         3     no  northwest  16455.70785
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 635    64    male  38.190         0     no  northeast  14410.93210
#
# [1338 rows x 7 columns]

# %%
ins_df.sort_values('bmi')
# Out:
#       age  gender     bmi  children smoker     region      charges
# 172    18    male  15.960         0     no  northeast   1694.79640
# 428    21  female  16.815         1     no  northeast   3167.45585
# 1226   38    male  16.815         2     no  northeast   6640.54485
# 412    26  female  17.195         2    yes  northeast  14455.64405
# 1286   28  female  17.290         0     no  northeast   3732.62510
# ...   ...     ...     ...       ...    ...        ...          ...
# 286    46  female  48.070         2     no  northeast   9432.92530
# 116    58    male  49.060         0     no  southeast  11381.32540
# 847    23    male  50.380         1     no  southeast   2438.05520
# 1047   22    male  52.580         1    yes  southeast  44501.39820
# 1317   18    male  53.130         0     no  southeast   1163.46270
#
# [1338 rows x 7 columns]

# %%
emp_df.head(2)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
#
#         City
# 0     Denver
# 1  Stonewall

# %%
emp_df.sort_values('Emp ID')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 37  134841      Donna       33.89             57            4.03  129836
# 11  153989       Jack       22.21             61            0.56   82965
# 93  158666    Rebecca       56.00             55           34.32  160043
# 9   162402      Diana       29.73             60            3.44   43010
# 66  183071     Andrea       32.08             52            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 50  958326      Larry       28.76             75            0.43   97904
# 21  969580    Matthew       23.77             56            1.47   52237
# 92  969964     Janice       37.57             56            0.93  147641
# 54  971640   Clarence       56.66             64            8.58  165272
# 20  979607      Carol       22.64             56            1.26   93967
#
#                        City
# 37                     Lima
# 11                Las Vegas
# ...

# %%
emp_df.sort_values('First Name')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 36  218791      Aaron       48.49             56           20.08   54402
# 43  247137       Alan       38.65             80           11.15  154810
# 41  227922     Amanda       35.02             40           10.28  114257
# 31  893212        Amy       36.14             52           14.17  112715
# 66  183071     Andrea       32.08             52            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 17  214352    Theresa       24.66             59            2.52  197537
# 19  622406     Thomas       49.85             73           19.15   73862
# 64  917937       Todd       25.93             74            1.22  163560
# 13  301576      Wayne       21.10             87            0.02   92758
# 78  806955    William       50.05             50           17.36   73734
#
#             City
# 36       Eckerty
# 43     Knoxville
# 41  Lake Charles
# 31         Kline
# ...

# %%
emp_df = pd.read_csv('Emp_data.csv').head(10)
emp_df
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df.sort_values('Weight in Kgs')
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 6  539712      Nancy       22.14             50            0.87   98189
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 9  162402      Diana       29.73             60            3.44   43010
# 2  428945        Joe       54.15             68            0.98   50155
#
#              City
# 7     Blanchester
# 8         Delmita
# 6         Atlanta
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 0          Denver
# 1       Stonewall
# ...

# %%
emp_df.sort_values(['Weight in Kgs','Salary'])
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 6  539712      Nancy       22.14             50            0.87   98189
# 3  408351      Diane       39.67             51           18.30  180294
# 5  499687    Patrick       34.86             58           12.02   72305
# 4  193819   Benjamin       40.31             58            4.01  117642
# 9  162402      Diana       29.73             60            3.44   43010
# 1  940761     Brenda       47.02             60            9.01   51063
# 0  677509       Lois       36.36             60           13.68  168251
# 2  428945        Joe       54.15             68            0.98   50155
#
#              City
# 7     Blanchester
# 8         Delmita
# 6         Atlanta
# 3        Hydetown
# 5       Macksburg
# 4         Fremont
# 9  Eureka Springs
# 1       Stonewall
# ...

# %%
emp_df.sort_values(['Weight in Kgs','Age in Yrs'])
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 6  539712      Nancy       22.14             50            0.87   98189
# 3  408351      Diane       39.67             51           18.30  180294
# 5  499687    Patrick       34.86             58           12.02   72305
# 4  193819   Benjamin       40.31             58            4.01  117642
# 9  162402      Diana       29.73             60            3.44   43010
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
#
#              City
# 7     Blanchester
# 8         Delmita
# 6         Atlanta
# 3        Hydetown
# 5       Macksburg
# 4         Fremont
# 9  Eureka Springs
# 0          Denver
# ...

# %%
emp_df.sort_values(['Weight in Kgs','Age in Yrs','First Name'])
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 6  539712      Nancy       22.14             50            0.87   98189
# 3  408351      Diane       39.67             51           18.30  180294
# 5  499687    Patrick       34.86             58           12.02   72305
# 4  193819   Benjamin       40.31             58            4.01  117642
# 9  162402      Diana       29.73             60            3.44   43010
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
#
#              City
# 7     Blanchester
# 8         Delmita
# 6         Atlanta
# 3        Hydetown
# 5       Macksburg
# 4         Fremont
# 9  Eureka Springs
# 0          Denver
# ...

# %% [markdown]
# #### Sorting in Descending Order

# %%
emp_df.sort_values('Weight in Kgs',ascending=False)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2  428945        Joe       54.15             68            0.98   50155
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 9  162402      Diana       29.73             60            3.44   43010
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 3  408351      Diane       39.67             51           18.30  180294
# 6  539712      Nancy       22.14             50            0.87   98189
# 8  477616    Frances       58.18             42           23.27  121587
# 7  380086      Carol       59.12             40           34.52   60918
#
#              City
# 2    Michigantown
# 0          Denver
# 1       Stonewall
# 9  Eureka Springs
# 4         Fremont
# 5       Macksburg
# 3        Hydetown
# 6         Atlanta
# ...

# %%
emp_df.sort_values(['Weight in Kgs','Age in Yrs','First Name'],ascending=False)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2  428945        Joe       54.15             68            0.98   50155
# 1  940761     Brenda       47.02             60            9.01   51063
# 0  677509       Lois       36.36             60           13.68  168251
# 9  162402      Diana       29.73             60            3.44   43010
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 3  408351      Diane       39.67             51           18.30  180294
# 6  539712      Nancy       22.14             50            0.87   98189
# 8  477616    Frances       58.18             42           23.27  121587
# 7  380086      Carol       59.12             40           34.52   60918
#
#              City
# 2    Michigantown
# 1       Stonewall
# 0          Denver
# 9  Eureka Springs
# 4         Fremont
# 5       Macksburg
# 3        Hydetown
# 6         Atlanta
# ...

# %%
emp_df
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df.sort_values('Emp ID')
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 9  162402      Diana       29.73             60            3.44   43010
# 4  193819   Benjamin       40.31             58            4.01  117642
# 7  380086      Carol       59.12             40           34.52   60918
# 3  408351      Diane       39.67             51           18.30  180294
# 2  428945        Joe       54.15             68            0.98   50155
# 8  477616    Frances       58.18             42           23.27  121587
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
#
#              City
# 9  Eureka Springs
# 4         Fremont
# 7     Blanchester
# 3        Hydetown
# 2    Michigantown
# 8         Delmita
# 5       Macksburg
# 6         Atlanta
# ...

# %% [markdown]
# ### 3. reset_index()

# %%
emp_df2 = emp_df.sort_values('Emp ID')
emp_df2
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 9  162402      Diana       29.73             60            3.44   43010
# 4  193819   Benjamin       40.31             58            4.01  117642
# 7  380086      Carol       59.12             40           34.52   60918
# 3  408351      Diane       39.67             51           18.30  180294
# 2  428945        Joe       54.15             68            0.98   50155
# 8  477616    Frances       58.18             42           23.27  121587
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
#
#              City
# 9  Eureka Springs
# 4         Fremont
# 7     Blanchester
# 3        Hydetown
# 2    Michigantown
# 8         Delmita
# 5       Macksburg
# 6         Atlanta
# ...

# %%
emp_df2.reset_index()
# Out:
#    index  Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  \
# 0      9  162402      Diana       29.73             60            3.44
# 1      4  193819   Benjamin       40.31             58            4.01
# 2      7  380086      Carol       59.12             40           34.52
# 3      3  408351      Diane       39.67             51           18.30
# 4      2  428945        Joe       54.15             68            0.98
# 5      8  477616    Frances       58.18             42           23.27
# 6      5  499687    Patrick       34.86             58           12.02
# 7      6  539712      Nancy       22.14             50            0.87
# 8      0  677509       Lois       36.36             60           13.68
# 9      1  940761     Brenda       47.02             60            9.01
#
#    Salary            City
# 0   43010  Eureka Springs
# 1  117642         Fremont
# 2   60918     Blanchester
# 3  180294        Hydetown
# 4   50155    Michigantown
# ...

# %%
emp_df2.reset_index(drop=True)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  162402      Diana       29.73             60            3.44   43010
# 1  193819   Benjamin       40.31             58            4.01  117642
# 2  380086      Carol       59.12             40           34.52   60918
# 3  408351      Diane       39.67             51           18.30  180294
# 4  428945        Joe       54.15             68            0.98   50155
# 5  477616    Frances       58.18             42           23.27  121587
# 6  499687    Patrick       34.86             58           12.02   72305
# 7  539712      Nancy       22.14             50            0.87   98189
# 8  677509       Lois       36.36             60           13.68  168251
# 9  940761     Brenda       47.02             60            9.01   51063
#
#              City
# 0  Eureka Springs
# 1         Fremont
# 2     Blanchester
# 3        Hydetown
# 4    Michigantown
# 5         Delmita
# 6       Macksburg
# 7         Atlanta
# ...

# %%
emp_df2 = emp_df.sort_values('Emp ID')
emp_df2.to_csv('EMP_Sorted_data.csv', index = False)

# %%
emp_df2 = emp_df.sort_values('Emp ID')
emp_df2.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### 4. set_index()

# %%
ins_df = pd.read_csv('medical_insurance.csv')

# %%
emp_df = pd.read_csv('Emp_data.csv').head(10)
emp_df
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df.set_index('Emp ID')
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 677509       Lois       36.36             60           13.68  168251
# 940761     Brenda       47.02             60            9.01   51063
# 428945        Joe       54.15             68            0.98   50155
# 408351      Diane       39.67             51           18.30  180294
# 193819   Benjamin       40.31             58            4.01  117642
# 499687    Patrick       34.86             58           12.02   72305
# 539712      Nancy       22.14             50            0.87   98189
# 380086      Carol       59.12             40           34.52   60918
# 477616    Frances       58.18             42           23.27  121587
# 162402      Diana       29.73             60            3.44   43010
#
#                   City
# Emp ID
# 677509          Denver
# 940761       Stonewall
# 428945    Michigantown
# 408351        Hydetown
# 193819         Fremont
# 499687       Macksburg
# ...

# %%
emp_df.set_index('Emp ID').sort_index()
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 162402      Diana       29.73             60            3.44   43010
# 193819   Benjamin       40.31             58            4.01  117642
# 380086      Carol       59.12             40           34.52   60918
# 408351      Diane       39.67             51           18.30  180294
# 428945        Joe       54.15             68            0.98   50155
# 477616    Frances       58.18             42           23.27  121587
# 499687    Patrick       34.86             58           12.02   72305
# 539712      Nancy       22.14             50            0.87   98189
# 677509       Lois       36.36             60           13.68  168251
# 940761     Brenda       47.02             60            9.01   51063
#
#                   City
# Emp ID
# 162402  Eureka Springs
# 193819         Fremont
# 380086     Blanchester
# 408351        Hydetown
# 428945    Michigantown
# 477616         Delmita
# ...

# %%
emp_df.set_index('First Name')
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36             60           13.68  168251
# Brenda      940761       47.02             60            9.01   51063
# Joe         428945       54.15             68            0.98   50155
# Diane       408351       39.67             51           18.30  180294
# Benjamin    193819       40.31             58            4.01  117642
# Patrick     499687       34.86             58           12.02   72305
# Nancy       539712       22.14             50            0.87   98189
# Carol       380086       59.12             40           34.52   60918
# Frances     477616       58.18             42           23.27  121587
# Diana       162402       29.73             60            3.44   43010
#
#                       City
# First Name
# Lois                Denver
# Brenda           Stonewall
# Joe           Michigantown
# Diane             Hydetown
# Benjamin           Fremont
# ...

# %%
emp_df.set_index('First Name').loc['Joe':'Nancy']
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Joe         428945       54.15             68            0.98   50155
# Diane       408351       39.67             51           18.30  180294
# Benjamin    193819       40.31             58            4.01  117642
# Patrick     499687       34.86             58           12.02   72305
# Nancy       539712       22.14             50            0.87   98189
#
#                     City
# First Name
# Joe         Michigantown
# Diane           Hydetown
# Benjamin         Fremont
# Patrick        Macksburg
# Nancy            Atlanta

# %%
emp_df.set_index('First Name').iloc[2:7]
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Joe         428945       54.15             68            0.98   50155
# Diane       408351       39.67             51           18.30  180294
# Benjamin    193819       40.31             58            4.01  117642
# Patrick     499687       34.86             58           12.02   72305
# Nancy       539712       22.14             50            0.87   98189
#
#                     City
# First Name
# Joe         Michigantown
# Diane           Hydetown
# Benjamin         Fremont
# Patrick        Macksburg
# Nancy            Atlanta

# %%
emp_df.set_index('First Name').iloc[2:7][['Emp ID','Salary']]
# Out:
#             Emp ID  Salary
# First Name
# Joe         428945   50155
# Diane       408351  180294
# Benjamin    193819  117642
# Patrick     499687   72305
# Nancy       539712   98189

# %% [markdown]
# ### 5. rename()

# %%
df.rename({Dict of Row Labels},axis = 0)
df.rename({Dict of Column Labels},axis = 1)

# %%
emp_df
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df.rename({'Emp ID':'EMP_ID'},axis = 1)
# Out:
#    EMP_ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df.rename({'Emp ID':'EMP_ID','First Name':'First_Name','Age in Yrs':'Age_in_Yrs',
              "Weight in Kgs":"Weight_in_Kgs", "Age in Company":"Age_in_Company"},axis = 1)
# Out:
#    EMP_ID First_Name  Age_in_Yrs  Weight_in_Kgs  Age_in_Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df.rename({'Emp ID':'EMP_ID','First Name':'First_Name','Age in Yrs':'Age_in_Yrs',
              "Weight in Kgs":"Weight_in_Kgs", "Age in Company":"Age_in_Company"},
              axis = 1, inplace=True)

emp_df
# Out:
#    EMP_ID First_Name  Age_in_Yrs  Weight_in_Kgs  Age_in_Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df['First_Name']
# Out:
# 0        Lois
# 1      Brenda
# 2         Joe
# 3       Diane
# 4    Benjamin
# 5     Patrick
# 6       Nancy
# 7       Carol
# 8     Frances
# 9       Diana
# Name: First_Name, dtype: object

# %%
emp_df.First_Name
# Out:
# 0        Lois
# 1      Brenda
# 2         Joe
# 3       Diane
# 4    Benjamin
# 5     Patrick
# 6       Nancy
# 7       Carol
# 8     Frances
# 9       Diana
# Name: First_Name, dtype: object

# %%
emp_df
# Out:
#    EMP_ID First_Name  Age_in_Yrs  Weight_in_Kgs  Age_in_Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df.rename({0:100,1:200,3:300},
              axis = 0, inplace=True)

emp_df
# Out:
#      EMP_ID First_Name  Age_in_Yrs  Weight_in_Kgs  Age_in_Company  Salary  \
# 100  677509       Lois       36.36             60           13.68  168251
# 200  940761     Brenda       47.02             60            9.01   51063
# 2    428945        Joe       54.15             68            0.98   50155
# 300  408351      Diane       39.67             51           18.30  180294
# 4    193819   Benjamin       40.31             58            4.01  117642
# 5    499687    Patrick       34.86             58           12.02   72305
# 6    539712      Nancy       22.14             50            0.87   98189
# 7    380086      Carol       59.12             40           34.52   60918
# 8    477616    Frances       58.18             42           23.27  121587
# 9    162402      Diana       29.73             60            3.44   43010
#
#                City
# 100          Denver
# 200       Stonewall
# 2      Michigantown
# 300        Hydetown
# 4           Fremont
# 5         Macksburg
# ...

# %%
array = np.random.randint(10,50,size = (6,5))
df = pd.DataFrame(array, columns=list("ABCDE"),index = list('python'))
df
# Out:
#     A   B   C   D   E
# p  44  12  47  14  44
# y  47  28  38  25  26
# t  25  26  23  48  12
# h  31  48  31  47  13
# o  31  38  33  25  49
# n  44  49  18  36  10

# %%
row_labels = {i:i.upper() for i in df.index}
row_labels
# Out:
# {'p': 'P', 'y': 'Y', 't': 'T', 'h': 'H', 'o': 'O', 'n': 'N'}

# %%
df.rename(row_labels,axis = 0)
# Out:
#     A   B   C   D   E
# P  44  12  47  14  44
# Y  47  28  38  25  26
# T  25  26  23  48  12
# H  31  48  31  47  13
# O  31  38  33  25  49
# N  44  49  18  36  10
