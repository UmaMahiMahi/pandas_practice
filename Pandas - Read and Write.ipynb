# %% [markdown]
# ### Pandas - Read and Write

# %%
import pandas as pd
import numpy as np

# %%
array = np.random.randint(10,30,size = (5,4))
df = pd.DataFrame(array, columns = list("ABCD"))
df
# Out:
#     A   B   C   D
# 0  14  25  14  26
# 1  12  10  26  17
# 2  26  16  13  13
# 3  22  26  29  29
# 4  24  21  29  13

# %%
df.to_csv('test.csv',header=False, index=False)

# %% [markdown]
# ### 1. Read CSV file

# %%
pd.read('csv_file_path')

# %%
df = pd.read_csv('Emp_data.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
csv_file_path = r"D:\Velocity Data Science\Dataset\diabetes.csv"
diabetes_df = pd.read_csv(csv_file_path)
diabetes_df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   52        1
# 3                       0.167   21        0
# ...

# %%
1M rows and 50 Columns
30 Columns

# %%
df = pd.read_csv('Emp_data.csv')[['Emp ID','First Name','Salary','City']]
df
# Out:
#     Emp ID First Name  Salary          City
# 0   677509       Lois  168251        Denver
# 1   940761     Brenda   51063     Stonewall
# 2   428945        Joe   50155  Michigantown
# 3   408351      Diane  180294      Hydetown
# 4   193819   Benjamin  117642       Fremont
# ..     ...        ...     ...           ...
# 95  639892       Jose  129774        Biloxi
# 96  704709     Harold  156194  Carol Stream
# 97  461593     Nicole   95673       Detroit
# 98  392491    Theresa   51015      Mc Grath
# 99  495141      Tammy   93650          Alma
#
# [100 rows x 4 columns]

# %%
df = pd.read_csv('Emp_data.csv', usecols = ['Emp ID','First Name','Salary','City'])
df
# Out:
#     Emp ID First Name  Salary          City
# 0   677509       Lois  168251        Denver
# 1   940761     Brenda   51063     Stonewall
# 2   428945        Joe   50155  Michigantown
# 3   408351      Diane  180294      Hydetown
# 4   193819   Benjamin  117642       Fremont
# ..     ...        ...     ...           ...
# 95  639892       Jose  129774        Biloxi
# 96  704709     Harold  156194  Carol Stream
# 97  461593     Nicole   95673       Detroit
# 98  392491    Theresa   51015      Mc Grath
# 99  495141      Tammy   93650          Alma
#
# [100 rows x 4 columns]

# %%
csv_file_path = r"D:\Velocity Data Science\Dataset\diabetes.csv"
diabetes_df = pd.read_csv(csv_file_path, usecols=['Glucose','BloodPressure','Age','Outcome'])
diabetes_df
# Out:
#      Glucose  BloodPressure  Age  Outcome
# 0        148             50   50        1
# 1         85             66   31        0
# 2        183             64   52        1
# 3        150             66   21        0
# 4        150             40   33        1
# ..       ...            ...  ...      ...
# 763      101             76   63        0
# 764      122             70   27        0
# 765      121             72   30        0
# 766      126             60   47        1
# 767       93             70   23        0
#
# [768 rows x 4 columns]

# %%
df = pd.read_csv('Emp_data.csv', usecols = ['Emp ID','First Name','Salary','City']).set_index('Emp ID')
df
# Out:
#        First Name  Salary          City
# Emp ID
# 677509       Lois  168251        Denver
# 940761     Brenda   51063     Stonewall
# 428945        Joe   50155  Michigantown
# 408351      Diane  180294      Hydetown
# 193819   Benjamin  117642       Fremont
# ...           ...     ...           ...
# 639892       Jose  129774        Biloxi
# 704709     Harold  156194  Carol Stream
# 461593     Nicole   95673       Detroit
# 392491    Theresa   51015      Mc Grath
# 495141      Tammy   93650          Alma
#
# [100 rows x 3 columns]

# %%
df = pd.read_csv('Emp_data.csv', usecols = ['Emp ID','First Name','Salary','City'], 
                index_col='Emp ID')
df
# Out:
#        First Name  Salary          City
# Emp ID
# 677509       Lois  168251        Denver
# 940761     Brenda   51063     Stonewall
# 428945        Joe   50155  Michigantown
# 408351      Diane  180294      Hydetown
# 193819   Benjamin  117642       Fremont
# ...           ...     ...           ...
# 639892       Jose  129774        Biloxi
# 704709     Harold  156194  Carol Stream
# 461593     Nicole   95673       Detroit
# 392491    Theresa   51015      Mc Grath
# 495141      Tammy   93650          Alma
#
# [100 rows x 3 columns]

# %%
df = pd.read_csv('Emp_data.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df = pd.read_csv('Employees.csv')
df
# Out:
#     677509      Lois  36.36  60  13.68  168251        Denver
# 0   940761    Brenda  47.02  60   9.01   51063     Stonewall
# 1   428945       Joe  54.15  68   0.98   50155  Michigantown
# 2   408351     Diane  39.67  51  18.30  180294      Hydetown
# 3   193819  Benjamin  40.31  58   4.01  117642       Fremont
# 4   499687   Patrick  34.86  58  12.02   72305     Macksburg
# ..     ...       ...    ...  ..    ...     ...           ...
# 94  639892      Jose  22.82  89   1.05  129774        Biloxi
# 95  704709    Harold  32.61  77   5.93  156194  Carol Stream
# 96  461593    Nicole  52.66  60  28.53   95673       Detroit
# 97  392491   Theresa  29.60  57   6.99   51015      Mc Grath
# 98  495141     Tammy  38.38  55   2.26   93650          Alma
#
# [99 rows x 7 columns]

# %%
df = pd.read_csv('Employees.csv')
df
# Out:
#     677509      Lois  36.36  60  13.68  168251        Denver
# 0   940761    Brenda  47.02  60   9.01   51063     Stonewall
# 1   428945       Joe  54.15  68   0.98   50155  Michigantown
# 2   408351     Diane  39.67  51  18.30  180294      Hydetown
# 3   193819  Benjamin  40.31  58   4.01  117642       Fremont
# 4   499687   Patrick  34.86  58  12.02   72305     Macksburg
# ..     ...       ...    ...  ..    ...     ...           ...
# 94  639892      Jose  22.82  89   1.05  129774        Biloxi
# 95  704709    Harold  32.61  77   5.93  156194  Carol Stream
# 96  461593    Nicole  52.66  60  28.53   95673       Detroit
# 97  392491   Theresa  29.60  57   6.99   51015      Mc Grath
# 98  495141     Tammy  38.38  55   2.26   93650          Alma
#
# [99 rows x 7 columns]

# %%
df = pd.read_csv('Employees.csv',header=None)
df
# Out:
#          0         1      2   3      4       5             6
# 0   677509      Lois  36.36  60  13.68  168251        Denver
# 1   940761    Brenda  47.02  60   9.01   51063     Stonewall
# 2   428945       Joe  54.15  68   0.98   50155  Michigantown
# 3   408351     Diane  39.67  51  18.30  180294      Hydetown
# 4   193819  Benjamin  40.31  58   4.01  117642       Fremont
# ..     ...       ...    ...  ..    ...     ...           ...
# 95  639892      Jose  22.82  89   1.05  129774        Biloxi
# 96  704709    Harold  32.61  77   5.93  156194  Carol Stream
# 97  461593    Nicole  52.66  60  28.53   95673       Detroit
# 98  392491   Theresa  29.60  57   6.99   51015      Mc Grath
# 99  495141     Tammy  38.38  55   2.26   93650          Alma
#
# [100 rows x 7 columns]

# %%
df = pd.read_csv('Test.csv', header=None)
df.columns = list("ASDF")
df
# Out:
#     A   S   D   F
# 0  14  25  14  26
# 1  12  10  26  17
# 2  26  16  13  13
# 3  22  26  29  29
# 4  24  21  29  13

# %%
df = pd.read_csv('Test.csv', header=None)
df.columns = list("ASDF")
df.index = list("pytho")
df
# Out:
#     A   S   D   F
# p  14  25  14  26
# y  12  10  26  17
# t  26  16  13  13
# h  22  26  29  29
# o  24  21  29  13

# %%
df = pd.read_csv('Emp_data.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City  test
# 0         Denver   NaN
# 1      Stonewall   NaN
# ...

# %%
df = pd.read_csv('Emp_data.csv')
# df

# %%
df = pd.read_csv('Emp_data.csv')
df
# Out:
#    Emp ID|First Name|Age in Yrs|Weight in Kgs|Age in Company|Salary|City
# 0            677509|Lois|36.36|60|13.68|168251|Denver
# 1         940761|Brenda|47.02|60|9.01|51063|Stonewall
# 2         428945|Joe|54.15|68|0.98|50155|Michigantown
# 3          408351|Diane|39.67|51|18.3|180294|Hydetown
# 4        193819|Benjamin|40.31|58|4.01|117642|Fremont
# ..                                                ...
# 95            639892|Jose|22.82|89|1.05|129774|Biloxi
# 96    704709|Harold|32.61|77|5.93|156194|Carol Stream
# 97         461593|Nicole|52.66|60|28.53|95673|Detroit
# 98         392491|Theresa|29.6|57|6.99|51015|Mc Grath
# 99              495141|Tammy|38.38|55|2.26|93650|Alma
#
# [100 rows x 1 columns]

# %%
df = pd.read_csv('Emp_data.csv',delimiter=',')
df
# Out:
#    Emp ID|First Name|Age in Yrs|Weight in Kgs|Age in Company|Salary
# 0            677509|Lois|36.36|60|13.68|168251|Denver
# 1         940761|Brenda|47.02|60|9.01|51063|Stonewall
# 2         428945|Joe|54.15|68|0.98|50155|Michigantown
# 3          408351|Diane|39.67|51|18.3|180294|Hydetown
# 4        193819|Benjamin|40.31|58|4.01|117642|Fremont
# ..                                                ...
# 95            639892|Jose|22.82|89|1.05|129774|Biloxi
# 96    704709|Harold|32.61|77|5.93|156194|Carol Stream
# 97         461593|Nicole|52.66|60|28.53|95673|Detroit
# 98         392491|Theresa|29.6|57|6.99|51015|Mc Grath
# 99              495141|Tammy|38.38|55|2.26|93650|Alma
#
# [100 rows x 1 columns]

# %%
df = pd.read_csv('Emp_data.csv',delimiter='|')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df = pd.read_csv('Emp_data.csv',delimiter='|')
df
# Out:
#           Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  \
# 677509      Lois       36.36          60          13.68          168251
# 940761    Brenda       47.02          60           9.01           51063
# 428945       Joe       54.15          68           0.98           50155
# 408351     Diane       39.67          51          18.30          180294
# 193819  Benjamin       40.31          58           4.01          117642
# ...          ...         ...         ...            ...             ...
# 639892      Jose       22.82          89           1.05          129774
# 704709    Harold       32.61          77           5.93          156194
# 461593    Nicole       52.66          60          28.53           95673
# 392491   Theresa       29.60          57           6.99           51015
# 495141     Tammy       38.38          55           2.26           93650
#
#          Salary,City
# 677509        Denver
# 940761     Stonewall
# 428945  Michigantown
# ...

# %% [markdown]
# ### 2. Create CSV Files

# %%
df.to_csv()

# %%
movies_df = pd.read_csv("Movies_Data.csv")
action_df = movies_df.groupby('genre').get_group('Action')
action_df
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
action_df.to_csv('action_movies.csv')

# %%
action_df.to_csv('action_movies.csv', index=False)

# %%
array = np.random.randint(10,30,size = (5,4))
df = pd.DataFrame(array)
df
# Out:
#     0   1   2   3
# 0  15  24  28  17
# 1  22  17  18  12
# 2  13  16  25  22
# 3  17  29  11  25
# 4  22  25  23  22

# %%
df.to_csv("Numbers.csv", index=False, header=False)

# %% [markdown]
# ### 3. Read Excel File

# %%
movies_df = pd.read_excel('Movies_Excel.xlsx')
movies_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies_df = pd.read_excel('Movies_Excel.xlsx', usecols=['title','genre'])
movies_df
# Out:
#                                                title      genre
# 0                           The Shawshank Redemption      Crime
# 1                                      The Godfather      Crime
# 2                             The Godfather: Part II      Crime
# 3                                    The Dark Knight     Action
# 4                                       Pulp Fiction      Crime
# ..                                               ...        ...
# 974                                          Tootsie     Comedy
# 975                      Back to the Future Part III  Adventure
# 976  Master and Commander: The Far Side of the World     Action
# 977                                      Poltergeist     Horror
# 978                                      Wall Street      Crime
#
# [979 rows x 2 columns]

# %%
movies_df = pd.read_excel('Movies_Excel.xlsx', index_col='title')
movies_df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
movies_df = pd.read_excel('Movies_Excel.xlsx',header=None)
movies_df
# Out:
#                0                                                1  \
# 0    star_rating                                            title
# 1            9.3                         The Shawshank Redemption
# 2            9.2                                    The Godfather
# 3            9.1                           The Godfather: Part II
# 4              9                                  The Dark Knight
# ..           ...                                              ...
# 975          7.4                                          Tootsie
# 976          7.4                      Back to the Future Part III
# 977          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Poltergeist
# 979          7.4                                      Wall Street
#
#                   2          3         4  \
# 0    content_rating      genre  duration
# 1                 R      Crime       142
# 2                 R      Crime       175
# ...

# %% [raw]
# movies_df = pd.read_excel('Movies_Excel.xlsx',header=None, index_col='title')
# movies_df

# %%
movies_df = pd.read_excel('Movies_Excel.xlsx',sheet_name='movies')
movies_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
sci_df = pd.read_excel('Movies_Excel.xlsx',sheet_name='sci')
sci_df
# Out:
#    star_rating                          title content_rating    genre  \
# 0          8.2                   Blade Runner              R   Sci-Fi
# 1          8.0                         Brazil              R   Sci-Fi
# 2          8.0            Battleship Potemkin        UNRATED  History
# 3          7.9                        Gravity          PG-13   Sci-Fi
# 4          7.8  The Day the Earth Stood Still       APPROVED   Sci-Fi
# 5          7.7           The Butterfly Effect              R   Sci-Fi
#
#    duration                                        actors_list
# 0       117  [u'Harrison Ford', u'Rutger Hauer', u'Sean You...
# 1       132  [u'Jonathan Pryce', u'Kim Greist', u'Robert De...
# 2        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 3        91  [u'Sandra Bullock', u'George Clooney', u'Ed Ha...
# 4        92  [u'Michael Rennie', u'Patricia Neal', u'Hugh M...
# 5       113  [u'Ashton Kutcher', u'Amy Smart', u'Melora Wal...

# %%
west_df = pd.read_excel('Movies_Excel.xlsx',sheet_name='western')
west_df
# Out:
#    star_rating                           title content_rating    genre  \
# 0          8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 1          8.6    Once Upon a Time in the West          PG-13  Western
# 2          8.5                Django Unchained              R  Western
# 3          8.3          For a Few Dollars More       APPROVED  Western
# 4          8.3                      Unforgiven              R  Western
# 5          8.1                       High Noon             PG  Western
# 6          8.1                       Rio Bravo      NOT RATED  Western
# 7          7.9          The Outlaw Josey Wales             PG  Western
# 8          7.6             High Plains Drifter              R  Western
#
#    duration                                        actors_list
# 0       161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 1       175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 2       165  [u'Jamie Foxx', u'Christoph Waltz', u'Leonardo...
# ...

# %% [markdown]
# ### Create Excel Files

# %% [raw]
# df.to_excel("excel_file_path.xlsx",sheet_name='Test', index=True, header=True)

# %%
movies_df = pd.read_csv("Movies_Data.csv")
movies_df
action_df = movies_df.groupby('genre').get_group('Action')
action_df
crime_df = movies_df.groupby('genre').get_group('Crime')
crime_df
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
movies_df.to_excel("Movies.xlsx", sheet_name='All_Movies',index = False)

# %%
action_df.to_excel("Movies.xlsx", sheet_name='Action',index = False)

# %%
crime_df.to_excel("Movies.xlsx", sheet_name='Crime',index = False)

# %%
Writer = pd.ExcelWriter('Movies.xlsx', engine='xlsxwriter')

movies_df.to_excel(Writer, sheet_name='All_Movies',index = False)
action_df.to_excel(Writer, sheet_name='Action',index = False)
Writer.save()

# %%
movies_df = pd.read_csv("Movies_Data.csv")
movies_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
genres_list = movies_df['genre'].unique()

# %%
movies_df = pd.read_csv("Movies_Data.csv")
genres_list = movies_df['genre'].unique()

XLWriter = pd.ExcelWriter("TEST_Movies.xlsx",engine='xlsxwriter')

for genre in genres_list:
    print('genre : ',genre)
    df = movies_df.groupby('genre').get_group(genre)
    df.to_excel(XLWriter, sheet_name=genre, index = False)
    
XLWriter.save()
# Out:
# genre :  Crime
# genre :  Action
# genre :  Drama
# genre :  Western
# genre :  Adventure
# genre :  Biography
# genre :  Comedy
# genre :  Animation
# genre :  Mystery
# genre :  Horror
# genre :  Film-Noir
# genre :  Sci-Fi
# genre :  History
# genre :  Thriller
# genre :  Family
# genre :  Fantasy

# %% [markdown]
# ### 5. Create a Dict

# %%
df = pd.read_csv('Emp_data.csv',usecols=['Emp ID', 'First Name', 'Salary', 'City']).head(5)
df
# Out:
#    Emp ID First Name  Salary          City
# 0  677509       Lois  168251        Denver
# 1  940761     Brenda   51063     Stonewall
# 2  428945        Joe   50155  Michigantown
# 3  408351      Diane  180294      Hydetown
# 4  193819   Benjamin  117642       Fremont

# %% [markdown]
# ##### Series to Dict

# %%
df['Emp ID'].to_dict()
# Out:
# {0: 677509, 1: 940761, 2: 428945, 3: 408351, 4: 193819}

# %%
df = pd.read_csv('Emp_data.csv',usecols=['Emp ID', 'First Name', 'Salary', 'City'], 
                 index_col='Emp ID').head(5)
df
# Out:
#        First Name  Salary          City
# Emp ID
# 677509       Lois  168251        Denver
# 940761     Brenda   51063     Stonewall
# 428945        Joe   50155  Michigantown
# 408351      Diane  180294      Hydetown
# 193819   Benjamin  117642       Fremont

# %%
df = pd.read_csv('Emp_data.csv',usecols=['Emp ID', 'First Name', 'Salary', 'City'], 
                 index_col='Emp ID').head(5)

df['First Name'].to_dict()
# Out:
# {677509: 'Lois',
#  940761: 'Brenda',
#  428945: 'Joe',
#  408351: 'Diane',
#  193819: 'Benjamin'}

# %% [markdown]
# ##### df to dict

# %%
df = pd.read_csv('Emp_data.csv',usecols=['Emp ID', 'First Name', 'Salary', 'City'], 
                 ).head(5)
df
# Out:
#    Emp ID First Name  Salary          City
# 0  677509       Lois  168251        Denver
# 1  940761     Brenda   51063     Stonewall
# 2  428945        Joe   50155  Michigantown
# 3  408351      Diane  180294      Hydetown
# 4  193819   Benjamin  117642       Fremont

# %%
df.to_dict()
# Out:
# {'Emp ID': {0: 677509, 1: 940761, 2: 428945, 3: 408351, 4: 193819},
#  'First Name': {0: 'Lois', 1: 'Brenda', 2: 'Joe', 3: 'Diane', 4: 'Benjamin'},
#  'Salary': {0: 168251, 1: 51063, 2: 50155, 3: 180294, 4: 117642},
#  'City': {0: 'Denver',
#   1: 'Stonewall',
#   2: 'Michigantown',
#   3: 'Hydetown',
#   4: 'Fremont'}}

# %%
df.to_dict(orient='dict')
# Out:
# {'Emp ID': {0: 677509, 1: 940761, 2: 428945, 3: 408351, 4: 193819},
#  'First Name': {0: 'Lois', 1: 'Brenda', 2: 'Joe', 3: 'Diane', 4: 'Benjamin'},
#  'Salary': {0: 168251, 1: 51063, 2: 50155, 3: 180294, 4: 117642},
#  'City': {0: 'Denver',
#   1: 'Stonewall',
#   2: 'Michigantown',
#   3: 'Hydetown',
#   4: 'Fremont'}}

# %%
df.to_dict(orient='list')
# Out:
# {'Emp ID': [677509, 940761, 428945, 408351, 193819],
#  'First Name': ['Lois', 'Brenda', 'Joe', 'Diane', 'Benjamin'],
#  'Salary': [168251, 51063, 50155, 180294, 117642],
#  'City': ['Denver', 'Stonewall', 'Michigantown', 'Hydetown', 'Fremont']}

# %%
data = {'Emp ID': [677509, 940761, 428945, 408351, 193819],
         'First Name': ['Lois', 'Brenda', 'Joe', 'Diane', 'Benjamin'],
         'Salary': [168251, 51063, 50155, 180294, 117642],
         'City': ['Denver', 'Stonewall', 'Michigantown', 'Hydetown', 'Fremont']}

df2 = pd.DataFrame(data)
df2
# Out:
#    Emp ID First Name  Salary          City
# 0  677509       Lois  168251        Denver
# 1  940761     Brenda   51063     Stonewall
# 2  428945        Joe   50155  Michigantown
# 3  408351      Diane  180294      Hydetown
# 4  193819   Benjamin  117642       Fremont

# %%
df.to_dict(orient='split')
# Out:
# {'index': [0, 1, 2, 3, 4],
#  'columns': ['Emp ID', 'First Name', 'Salary', 'City'],
#  'data': [[677509, 'Lois', 168251, 'Denver'],
#   [940761, 'Brenda', 51063, 'Stonewall'],
#   [428945, 'Joe', 50155, 'Michigantown'],
#   [408351, 'Diane', 180294, 'Hydetown'],
#   [193819, 'Benjamin', 117642, 'Fremont']]}

# %%
df.to_dict(orient='records') # Rows wise
# Out:
# [{'Emp ID': 677509, 'First Name': 'Lois', 'Salary': 168251, 'City': 'Denver'},
#  {'Emp ID': 940761,
#   'First Name': 'Brenda',
#   'Salary': 51063,
#   'City': 'Stonewall'},
#  {'Emp ID': 428945,
#   'First Name': 'Joe',
#   'Salary': 50155,
#   'City': 'Michigantown'},
#  {'Emp ID': 408351,
#   'First Name': 'Diane',
#   'Salary': 180294,
#   'City': 'Hydetown'},
#  {'Emp ID': 193819,
#   'First Name': 'Benjamin',
#   'Salary': 117642,
#   'City': 'Fremont'}]

# %% [markdown]
# ### 6. Create JSON Files

# %%
df
# Out:
#    Emp ID First Name  Salary          City
# 0  677509       Lois  168251        Denver
# 1  940761     Brenda   51063     Stonewall
# 2  428945        Joe   50155  Michigantown
# 3  408351      Diane  180294      Hydetown
# 4  193819   Benjamin  117642       Fremont

# %%
df.to_json("EMP_JSON.json")

# %%
df.to_json("EMP_JSON_index.json", orient='index')

# %%
df.to_json("EMP_JSON_records.json", orient='records')

# %% [markdown]
# ### Read JSON Files

# %%
pd.read_json('EMP_JSON.json')
# Out:
#    Emp ID First Name  Salary          City
# 0  677509       Lois  168251        Denver
# 1  940761     Brenda   51063     Stonewall
# 2  428945        Joe   50155  Michigantown
# 3  408351      Diane  180294      Hydetown
# 4  193819   Benjamin  117642       Fremont

# %%
pd.read_json('EMP_JSON_index.json')
# Out:
#    Emp ID First Name  Salary          City
# 0  677509       Lois  168251        Denver
# 1  940761     Brenda   51063     Stonewall
# 2  428945        Joe   50155  Michigantown
# 3  408351      Diane  180294      Hydetown
# 4  193819   Benjamin  117642       Fremont
