# %% [markdown]
# ### Pandas - GroupBy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Functions

# %%
1. groupby:
    1. df.groupby('ColName')
    2. df.groupby('ColName').groups['ColValues']
    3. df.groupby('ColName').groups.keys()
    4. df.groupby('ColName').first()
    5. df.groupby('ColName').get_groups('ColValues')
    6. df.groupby(['ColName1','ColName2']).get_groups(('Col_1_Values','Col2_values'))
    7. df.groupby('genre')['duration'].mean()
    8. df.groupby('genre')['duration'].max()
    9. df.groupby('genre')['duration'].min()

2. Loc:
    1. df['genre'] == 'Action'
    2. df.loc[conditions]
    3. df.loc[df['genre'] == 'Action']
    4. df.loc[(df['genre'] == 'Action') &
              (df['content_rating'] == 'APPROVED')]
        
    5. df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))
      ][['title','genre','duration']]
    
3. isin():
    1. df['genre'].isin(['Action','Biography','Crime','Adventure'])
    2. df.loc[df['genre'].isin(["Action",'Biography','Crime','Adventure'])
      
       & (df['content_rating'].isin([ "PG-13",'PG','R']))
       
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))]

# %%
1. groupby:
    1. df.groupby('ColName')
    2. df.groupby('ColName').groups['ColValues']
    3. df.groupby('ColName').groups.keys()
    4. df.groupby('ColName').first()
    5. df.groupby('ColName').get_groups('ColValues')
    6. df.groupby(['ColName1','ColName2']).get_groups(('Col_1_Values','Col2_values'))
    7. df.groupby('genre')['duration'].mean()
    8. df.groupby('genre')['duration'].max()
    9. df.groupby('genre')['duration'].min()

2. Loc:
    1. df['genre'] == 'Action'
    2. df.loc[conditions]
    3. df.loc[df['genre'] == 'Action']
    4. df.loc[(df['genre'] == 'Action') &
              (df['content_rating'] == 'APPROVED')]
        
    5. df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))
      ][['title','genre','duration']]
    
3. isin():
    1. df['genre'].isin(['Action','Biography','Crime','Adventure'])
    2. df.loc[df['genre'].isin(["Action",'Biography','Crime','Adventure'])
      
       & (df['content_rating'].isin([ "PG-13",'PG','R']))
       
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))]

# %%
df = pd.read_csv('movies_data.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.groupby('genre')

# %%
df.groupby('genre').groups["Action"]
# Out:
# Int64Index([  3,  11,  12,  19,  20,  36,  37,  43,  44,  45,
#             ...
#             884, 885, 896, 906, 908, 918, 954, 963, 967, 976],
#            dtype='int64', length=136)

# %%
df.groupby('genre').groups['Comedy']
# Out:
# Int64Index([ 25,  29,  35,  48,  52,  60,  66,  70,  88,  93,
#             ...
#             948, 949, 952, 956, 957, 959, 960, 962, 971, 974],
#            dtype='int64', length=156)

# %%
# df.groupby('genre').groups

# %%
df.groupby('genre').groups.keys()
# Out:
# dict_keys(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'History', 'Horror', 'Mystery', 'Sci-Fi', 'Thriller', 'Western'])

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df.groupby('genre').groups['Crime']
# Out:
# Int64Index([  0,   1,   2,   4,  21,  23,  28,  34,  40,  49,
#             ...
#             893, 907, 915, 920, 924, 927, 931, 950, 969, 978],
#            dtype='int64', length=124)

# %%
df.groupby('content_rating').groups.keys()
# Out:
# dict_keys(['APPROVED', 'G', 'GP', 'NC-17', 'NOT RATED', 'PASSED', 'PG', 'PG-13', 'R', 'TV-MA', 'UNRATED', 'X'])

# %%
df.head(20)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
df.groupby('genre').first()
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
df.groupby('genre').get_group('Comedy')
# Out:
#      star_rating                                              title  \
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 52           8.5                                 The Great Dictator
# ..           ...                                                ...
# 959          7.4                               Deconstructing Harry
# 960          7.4                                   The Way Way Back
# 962          7.4                                 Driving Miss Daisy
# 971          7.4                                 Death at a Funeral
# 974          7.4                                            Tootsie
#
#     content_rating   genre  duration  \
# 25           PG-13  Comedy       116
# 29          PASSED  Comedy        87
# ...

# %%
comedy_df = df.groupby('genre').get_group('Comedy')
comedy_df
# Out:
#      star_rating                                              title  \
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 52           8.5                                 The Great Dictator
# ..           ...                                                ...
# 959          7.4                               Deconstructing Harry
# 960          7.4                                   The Way Way Back
# 962          7.4                                 Driving Miss Daisy
# 971          7.4                                 Death at a Funeral
# 974          7.4                                            Tootsie
#
#     content_rating   genre  duration  \
# 25           PG-13  Comedy       116
# 29          PASSED  Comedy        87
# ...

# %%
test_df = df.groupby('content_rating').get_group('PASSED')
test_df
# Out:
#      star_rating                        title content_rating      genre  \
# 29           8.6                  City Lights         PASSED     Comedy
# 79           8.4             Double Indemnity         PASSED      Crime
# 159          8.2  The Best Years of Our Lives         PASSED      Drama
# 224          8.1             The Wizard of Oz         PASSED  Adventure
# 293          8.1                    Duck Soup         PASSED     Comedy
# 358          8.0            The Lady Vanishes         PASSED     Comedy
# 619          7.7             Forbidden Planet         PASSED     Action
#
#      duration                                        actors_list
# 29         87  [u'Charles Chaplin', u'Virginia Cherrill', u'F...
# 79        107  [u'Fred MacMurray', u'Barbara Stanwyck', u'Edw...
# 159       172  [u'Fredric March', u'Dana Andrews', u'Myrna Loy']
# 224       102  [u'Judy Garland', u'Frank Morgan', u'Ray Bolger']
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# ...

# %%
test_df.to_csv('passed_movies.csv')

# %%
action_df = df.groupby('genre').get_group('Action').reset_index(drop = True)
action_df
# Out:
#      star_rating                                            title  \
# 0            9.0                                  The Dark Knight
# 1            8.8                                        Inception
# 2            8.8   Star Wars: Episode V - The Empire Strikes Back
# 3            8.7                                        Star Wars
# 4            8.7                                       The Matrix
# ..           ...                                              ...
# 131          7.5                                   Running Scared
# 132          7.4                                            X-Men
# 133          7.4                                  La Femme Nikita
# 134          7.4                                         The Rock
# 135          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 0            PG-13  Action       152
# 1            PG-13  Action       148
# 2               PG  Action       124
# ...

# %%
action_df = df.groupby(['genre','content_rating']).get_group(('Action','PG')).reset_index(drop = True)
action_df
# Out:
#     star_rating                                           title  \
# 0           8.8  Star Wars: Episode V - The Empire Strikes Back
# 1           8.7                                       Star Wars
# 2           8.6                         Raiders of the Lost Ark
# 3           8.4      Star Wars: Episode VI - Return of the Jedi
# 4           8.0                    The Adventures of Robin Hood
# 5           7.9                       The Man Who Would Be King
# 6           7.7                 Star Trek II: The Wrath of Khan
# 7           7.6                        The Hunt for Red October
# 8           7.6                            Escape from Alcatraz
# 9           7.6            Indiana Jones and the Temple of Doom
# 10          7.5                                         Bullitt
#
#    content_rating   genre  duration  \
# 0              PG  Action       124
# 1              PG  Action       121
# 2              PG  Action       115
# 3              PG  Action       134
# ...

# %%
action_df = df.groupby(['genre']).get_group(('Action')).reset_index(drop = True)
action_df
# Out:
#      star_rating                                            title  \
# 0            9.0                                  The Dark Knight
# 1            8.8                                        Inception
# 2            8.8   Star Wars: Episode V - The Empire Strikes Back
# 3            8.7                                        Star Wars
# 4            8.7                                       The Matrix
# ..           ...                                              ...
# 131          7.5                                   Running Scared
# 132          7.4                                            X-Men
# 133          7.4                                  La Femme Nikita
# 134          7.4                                         The Rock
# 135          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 0            PG-13  Action       152
# 1            PG-13  Action       148
# 2               PG  Action       124
# ...

# %% [markdown]
# ### groupby on numeric columns

# %% [raw]
# Average duration of all action movies

# %%
df.groupby('genre').get_group('Action')['duration'].mean()
# Out:
# 126.48529411764706

# %%
df.groupby('content_rating').get_group('PG')['star_rating'].mean()
# Out:
# 7.879674796747967

# %%
df.groupby(['content_rating','genre']).get_group(('PG','Action'))
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 37           8.6                         Raiders of the Lost Ark
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 327          8.0                    The Adventures of Robin Hood
# 420          7.9                       The Man Who Would Be King
# 586          7.7                 Star Trek II: The Wrath of Khan
# 748          7.6                        The Hunt for Red October
# 753          7.6                            Escape from Alcatraz
# 764          7.6            Indiana Jones and the Temple of Doom
# 908          7.5                                         Bullitt
#
#     content_rating   genre  duration  \
# 12              PG  Action       124
# 19              PG  Action       121
# 37              PG  Action       115
# ...

# %%
df.groupby(['content_rating','genre']).get_group(('PG','Action'))['star_rating'].mean()
# Out:
# 8.036363636363635

# %%
df.groupby(['content_rating','genre']).get_group(('PG','Action'))['star_rating'].max()
# Out:
# 8.8

# %%
df.groupby(['content_rating','genre']).get_group(('PG','Action'))['star_rating'].min()
# Out:
# 7.5

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.groupby('genre')['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
df.groupby('genre')['duration'].mean().sort_values()
# Out:
# genre
# History       66.000000
# Animation     96.596774
# Film-Noir     97.333333
# Horror       102.517241
# Family       107.500000
# Comedy       107.602564
# Sci-Fi       109.000000
# Fantasy      112.000000
# Thriller     114.200000
# Mystery      115.625000
# Crime        122.298387
# Action       126.485294
# Drama        126.539568
# Biography    131.844156
# Adventure    134.840000
# Western      136.666667
# Name: duration, dtype: float64

# %%
x_df = df.groupby('genre')['duration'].mean().sort_values(ascending = False)

# %%
x_df = df.groupby('genre')['duration'].mean()

# %%
x_df.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
x_df.plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='genre'>

# %%
plt.figure(figsize= (10,7))
x_df.plot(kind = 'barh')
plt.xlabel('Movies Duration')
plt.title("Average Duations of Movies")
# Out:
# Text(0.5, 1.0, 'Average Duations of Movies')

# %%
plt.figure(figsize= (10,7))
x_df.plot(kind = 'barh')
plt.xlabel('Movies Duration')
plt.title("Average Duations of Movies")
plt.savefig('movies_duation_mean.png')

# %%
df.groupby('genre')['duration'].max()
# Out:
# genre
# Action       205
# Adventure    224
# Animation    134
# Biography    202
# Comedy       187
# Crime        229
# Drama        242
# Family       115
# Fantasy      112
# Film-Noir    111
# History       66
# Horror       146
# Mystery      160
# Sci-Fi       132
# Thriller     120
# Western      175
# Name: duration, dtype: int64

# %%
df.groupby('genre')['duration'].min()
# Out:
# genre
# Action        80
# Adventure     89
# Animation     75
# Biography     85
# Comedy        68
# Crime         67
# Drama         64
# Family       100
# Fantasy      112
# Film-Noir     88
# History       66
# Horror        70
# Mystery       69
# Sci-Fi        91
# Thriller     107
# Western       85
# Name: duration, dtype: int64

# %% [markdown]
# ### Loc Function

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.loc[:,:]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.loc[:]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.loc[[2,6,7,9,500]]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 6            8.9                 The Good, the Bad and the Ugly
# 7            8.9  The Lord of the Rings: The Return of the King
# 9            8.9                                     Fight Club
# 500          7.8                              American Gangster
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 6        NOT RATED    Western       161
# 7            PG-13  Adventure       201
# 9                R      Drama       139
# 500              R  Biography       157
#
#                                            actors_list
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 6    [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 9    [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 500  [u'Denzel Washington', u'Russell Crowe', u'Chi...

# %%
df.loc[[2,6,7,9,500],['title','genre','star_rating']]
# Out:
#                                              title      genre  star_rating
# 2                           The Godfather: Part II      Crime          9.1
# 6                   The Good, the Bad and the Ugly    Western          8.9
# 7    The Lord of the Rings: The Return of the King  Adventure          8.9
# 9                                       Fight Club      Drama          8.9
# 500                              American Gangster  Biography          7.8

# %%
df.loc[:,['title','genre','star_rating']]
# Out:
#                                                title      genre  star_rating
# 0                           The Shawshank Redemption      Crime          9.3
# 1                                      The Godfather      Crime          9.2
# 2                             The Godfather: Part II      Crime          9.1
# 3                                    The Dark Knight     Action          9.0
# 4                                       Pulp Fiction      Crime          8.9
# ..                                               ...        ...          ...
# 974                                          Tootsie     Comedy          7.4
# 975                      Back to the Future Part III  Adventure          7.4
# 976  Master and Commander: The Far Side of the World     Action          7.4
# 977                                      Poltergeist     Horror          7.4
# 978                                      Wall Street      Crime          7.4
#
# [979 rows x 3 columns]

# %%
df.loc[:,:]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df['genre'] == "Horror"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977     True
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
df['genre'] == "Crime"
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
df['content_rating'] == "PG-13"]
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978    False
# Name: content_rating, Length: 979, dtype: bool

# %%
df.head(20)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
((df['content_rating'] == "PG") & (df['genre'] == "Action"))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 979, dtype: bool

# %%
df.loc[df['genre'] == "Action"]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df.loc[(df['genre'] == "Action") | (df['genre'] == "Biography")]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 8            8.9                                 Schindler's List
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 18           8.7                                       Goodfellas
# ..           ...                                              ...
# 961          7.4                                           Capote
# 963          7.4                                  La Femme Nikita
# 964          7.4                                          Lincoln
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 8                R  Biography       195
# 11           PG-13     Action       148
# ...

# %%
df.loc[(df['genre'] == "Action") & (df['genre'] == "Biography")]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
df.loc[(df['genre'] == "Action") & (df['content_rating'] == "PG-13")].shape
# Out:
# (44, 6)

# %%
df.loc[(df['genre'] == "Action") & (df['content_rating'] == "PG-13")]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 43           8.5                            The Dark Knight Rises
# 113          8.3                                    Batman Begins
# 118          8.3               Indiana Jones and the Last Crusade
# 177          8.2                                     The Avengers
# 196          8.1                          Guardians of the Galaxy
# 240          8.1                             The Bourne Ultimatum
# 248          8.1                       X-Men: Days of Future Past
# 301          8.0                                        Furious 7
# 312          8.0                                        Star Trek
# 366          8.0                                         Serenity
# 380          8.0                                    Casino Royale
# ...

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & (df['content_rating'] == "PG-13")]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 43           8.5                            The Dark Knight Rises
# 113          8.3                                    Batman Begins
# 118          8.3               Indiana Jones and the Last Crusade
# ..           ...                                              ...
# 876          7.5                                  Freedom Writers
# 888          7.5                                      The Aviator
# 954          7.4                                            X-Men
# 964          7.4                                          Lincoln
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 11           PG-13     Action       148
# 43           PG-13     Action       165
# ...

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & (df['content_rating'] == "PG-13")
       & (df['duration'] >= 120)].shape
# Out:
# (55, 6)

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & (df['content_rating'] == "PG-13")
       & ((df['duration'] >= 120) | (df['duration'] <= 180))
      ].shape
# Out:
# (73, 6)

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & (df['content_rating'] == "PG-13")
       & ((df['duration'] >= 120) & (df['duration'] <= 180))
      ].shape
# Out:
# (53, 6)

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & (df['content_rating'] == "PG-13")
       & ((df['duration'] >= 120) & (df['duration'] <= 150))
      ].shape
# Out:
# (46, 6)

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & (df['content_rating'] == "PG-13")
       & ((df['duration'] >= 120) & (df['duration'] <= 150))
      ]
# Out:
#      star_rating                                            title  \
# 11           8.8                                        Inception
# 113          8.3                                    Batman Begins
# 118          8.3               Indiana Jones and the Last Crusade
# 170          8.2                                 A Beautiful Mind
# 177          8.2                                     The Avengers
# 196          8.1                          Guardians of the Galaxy
# 248          8.1                       X-Men: Days of Future Past
# 260          8.1                                   The Sea Inside
# 301          8.0                                        Furious 7
# 312          8.0                                        Star Trek
# 340          8.0                              Catch Me If You Can
# 341          8.0                                   Cinderella Man
# 380          8.0                                    Casino Royale
# ...

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & (df['content_rating'] == "PG-13")
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8))
      ]
# Out:
#      star_rating                               title content_rating  \
# 11           8.8                           Inception          PG-13
# 113          8.3                       Batman Begins          PG-13
# 118          8.3  Indiana Jones and the Last Crusade          PG-13
# 170          8.2                    A Beautiful Mind          PG-13
# 177          8.2                        The Avengers          PG-13
# 196          8.1             Guardians of the Galaxy          PG-13
# 248          8.1          X-Men: Days of Future Past          PG-13
# 260          8.1                      The Sea Inside          PG-13
# 301          8.0                           Furious 7          PG-13
# 312          8.0                           Star Trek          PG-13
# 340          8.0                 Catch Me If You Can          PG-13
# 341          8.0                      Cinderella Man          PG-13
# 380          8.0                       Casino Royale          PG-13
#
# ...

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & (df['content_rating'] == "PG-13")
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8))
      ].sort_values('duration')
# Out:
#      star_rating                               title content_rating  \
# 196          8.1             Guardians of the Galaxy          PG-13
# 260          8.1                      The Sea Inside          PG-13
# 118          8.3  Indiana Jones and the Last Crusade          PG-13
# 312          8.0                           Star Trek          PG-13
# 248          8.1          X-Men: Days of Future Past          PG-13
# 170          8.2                    A Beautiful Mind          PG-13
# 301          8.0                           Furious 7          PG-13
# 113          8.3                       Batman Begins          PG-13
# 340          8.0                 Catch Me If You Can          PG-13
# 177          8.2                        The Avengers          PG-13
# 341          8.0                      Cinderella Man          PG-13
# 380          8.0                       Casino Royale          PG-13
# 11           8.8                           Inception          PG-13
#
# ...

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))
      ].sort_values('duration')
# Out:
#      star_rating                                           title  \
# 19           8.7                                       Star Wars
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 118          8.3              Indiana Jones and the Last Crusade
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 113          8.3                                   Batman Begins
# 11           8.8                                       Inception
#
#     content_rating   genre  duration  \
# 19              PG  Action       121
# 12              PG  Action       124
# 118          PG-13  Action       127
# 80              PG  Action       134
# 113          PG-13  Action       140
# 11           PG-13  Action       148
#
#                                            actors_list
# 19   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 12   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 118  [u'Harrison Ford', u'Sean Connery', u'Alison D...
# ...

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))
       , 'title'
      ]
# Out:
# 11                                          Inception
# 12     Star Wars: Episode V - The Empire Strikes Back
# 19                                          Star Wars
# 80         Star Wars: Episode VI - Return of the Jedi
# 113                                     Batman Begins
# 118                Indiana Jones and the Last Crusade
# Name: title, dtype: object

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))
       , ['title']
      ]
# Out:
#                                               title
# 11                                        Inception
# 12   Star Wars: Episode V - The Empire Strikes Back
# 19                                        Star Wars
# 80       Star Wars: Episode VI - Return of the Jedi
# 113                                   Batman Begins
# 118              Indiana Jones and the Last Crusade

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))
       , ['title','genre','duration']
      ]
# Out:
#                                               title   genre  duration
# 11                                        Inception  Action       148
# 12   Star Wars: Episode V - The Empire Strikes Back  Action       124
# 19                                        Star Wars  Action       121
# 80       Star Wars: Episode VI - Return of the Jedi  Action       134
# 113                                   Batman Begins  Action       140
# 118              Indiana Jones and the Last Crusade  Action       127

# %%
df[['title','genre','duration']]
# Out:
#                                                title      genre  duration
# 0                           The Shawshank Redemption      Crime       142
# 1                                      The Godfather      Crime       175
# 2                             The Godfather: Part II      Crime       200
# 3                                    The Dark Knight     Action       152
# 4                                       Pulp Fiction      Crime       154
# ..                                               ...        ...       ...
# 974                                          Tootsie     Comedy       116
# 975                      Back to the Future Part III  Adventure       118
# 976  Master and Commander: The Far Side of the World     Action       138
# 977                                      Poltergeist     Horror       114
# 978                                      Wall Street      Crime       126
#
# [979 rows x 3 columns]

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))
      ][['title','genre','duration']]
# Out:
#                                               title   genre  duration
# 11                                        Inception  Action       148
# 12   Star Wars: Episode V - The Empire Strikes Back  Action       124
# 19                                        Star Wars  Action       121
# 80       Star Wars: Episode VI - Return of the Jedi  Action       134
# 113                                   Batman Begins  Action       140
# 118              Indiana Jones and the Last Crusade  Action       127

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3)),'title'
      ]
# Out:
# 11                                          Inception
# 12     Star Wars: Episode V - The Empire Strikes Back
# 19                                          Star Wars
# 80         Star Wars: Episode VI - Return of the Jedi
# 113                                     Batman Begins
# 118                Indiana Jones and the Last Crusade
# Name: title, dtype: object

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography")) 
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") )
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3)),'title'
      ].tolist()
# Out:
# ['Inception',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'Star Wars',
#  'Star Wars: Episode VI - Return of the Jedi',
#  'Batman Begins',
#  'Indiana Jones and the Last Crusade']

# %%
df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df.content_rating.unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
df.loc[((df['genre'] == "Action") | 
        (df['genre'] == "Biography") | (df['genre'] == "Crime") | 
        (df['genre'] == "Adventure")) 
       
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") |
         (df['content_rating'] == "R"))
       
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))
      ]
# Out:
#      star_rating                                           title  \
# 0            9.3                        The Shawshank Redemption
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 18           8.7                                      Goodfellas
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 21           8.7                                     City of God
# 42           8.5                                     The Pianist
# 45           8.5                      Terminator 2: Judgment Day
# 68           8.4                                        Das Boot
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 112          8.3                               L.A. Confidential
# ...

# %%
(df['genre'] == 'Action')
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
df['genre'].isin(['Action','Biography','Crime','Adventure'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 974    False
# 975     True
# 976     True
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
df.loc[df['genre'].isin(["Action",'Biography','Crime','Adventure'])
      
       & ((df['content_rating'] == "PG-13") |(df['content_rating'] == "PG") |
         (df['content_rating'] == "R"))
       
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))]
# Out:
#      star_rating                                           title  \
# 0            9.3                        The Shawshank Redemption
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 18           8.7                                      Goodfellas
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 21           8.7                                     City of God
# 42           8.5                                     The Pianist
# 45           8.5                      Terminator 2: Judgment Day
# 68           8.4                                        Das Boot
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 112          8.3                               L.A. Confidential
# ...

# %%
df.loc[df['genre'].isin(["Action",'Biography','Crime','Adventure'])
      
       & (df['content_rating'].isin([ "PG-13",'PG','R']))
       
       & ((df['duration'] >= 120) & (df['duration'] <= 150)
       & (df['star_rating'] >= 8.3))]
# Out:
#      star_rating                                           title  \
# 0            9.3                        The Shawshank Redemption
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 18           8.7                                      Goodfellas
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 21           8.7                                     City of God
# 42           8.5                                     The Pianist
# 45           8.5                      Terminator 2: Judgment Day
# 68           8.4                                        Das Boot
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 112          8.3                               L.A. Confidential
# ...

# %%
array = np.random.randint(10,50,size = 10)
array
# Out:
# array([33, 24, 30, 47, 40, 25, 45, 44, 24, 36])

# %%
array >= 30
# Out:
# array([ True, False,  True,  True,  True, False,  True,  True, False,
#         True])

# %%
(array >= 30) & (array <= 40)
# Out:
# array([ True, False,  True, False,  True, False, False, False, False,
#         True])

# %%
np.where((array >= 30) & (array <= 40))
# Out:
# (array([0, 2, 4, 9], dtype=int64),)

# %%
np.where((array >= 30) & (array <= 40),100, 200)
# Out:
# array([100, 200, 100, 200, 100, 200, 200, 200, 200, 100])
