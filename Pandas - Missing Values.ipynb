# %% [markdown]
# ### Pandas - Missing Values

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Functions

# %%
1. Detect Missing Values:
    1. df.isna()
    2. df.isnull()
    3. df.isna().sum()
    4. df.isna().mean()
    5. df.isna().mean() * 100
    
2. Drop Null Values:
    1. df.dropna():
        1. df.dropna(thresh=df.shape[1], axis = 0)
        2. df.dropna(thresh=df.shape[0], axis = 1)
        
    2. df.drop():
        df.drop('ColName', axis = 1)
        df.drop(['Col1', 'Col2', ...,'ColN'], axis = 1)
        df.drop(['Row1', 'Row2',..., 'RowN'], axis = 0)
    
    
3. Imputation:
    1. df.fillna()
        Replace Missing values by using Stats:

        Continuous Data:
            1. df['ColName'].mean()
            2. df['ColName'].median()

        Categorical Data:
            1. df['ColName'].mode()[0]

# %%
array = np.random.randint(5,50, size = (7,4))
array
# Out:
# array([[48, 35, 15, 33],
#        [14, 48, 38, 31],
#        [27, 13, 16, 43],
#        [29, 42, 44, 38],
#        [34, 25, 14, 12],
#        [ 6, 26, 24, 30],
#        [18, 19, 45, 27]])

# %%
df = pd.DataFrame(array, columns=list("ABCD"))
df
# Out:
#     A   B   C   D
# 0  48  35  15  33
# 1  14  48  38  31
# 2  27  13  16  43
# 3  29  42  44  38
# 4  34  25  14  12
# 5   6  26  24  30
# 6  18  19  45  27

# %%
emp_df = pd.read_csv("Emp_data.csv")
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       7 non-null      int32
#  1   B       7 non-null      int32
#  2   C       7 non-null      int32
#  3   D       7 non-null      int32
# dtypes: int32(4)
# memory usage: 240.0 bytes

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   100 non-null    int64
#  4   Age in Company  100 non-null    float64
#  5   Salary          100 non-null    int64
#  6   City            100 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 5.6+ KB

# %% [markdown]
# ### Detect Missing Values

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False  False

# %%
df.isnull()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False  False

# %%
emp_df.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1    False       False       False          False           False   False
# 2    False       False       False          False           False   False
# 3    False       False       False          False           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 95  False
# 96  False
# 97  False
# 98  False
# 99  False
#
# [100 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# A    0
# B    0
# C    0
# D    0
# dtype: int64

# %%
df
# Out:
#     A   B   C   D
# 0  48  35  15  33
# 1  14  48  38  31
# 2  27  13  16  43
# 3  29  42  44  38
# 4  34  25  14  12
# 5   6  26  24  30
# 6  18  19  45  27

# %%
df.iloc[2:4, 1] = np.nan
df
# Out:
#     A     B   C   D
# 0  48  35.0  15  33
# 1  14  48.0  38  31
# 2  27   NaN  16  43
# 3  29   NaN  44  38
# 4  34  25.0  14  12
# 5   6  26.0  24  30
# 6  18  19.0  45  27

# %%
df.loc[[1,2,5],'D'] = np.nan
df
# Out:
#     A     B   C     D
# 0  48  35.0  15  33.0
# 1  14  48.0  38   NaN
# 2  27   NaN  16   NaN
# 3  29   NaN  44  38.0
# 4  34  25.0  14  12.0
# 5   6  26.0  24   NaN
# 6  18  19.0  45  27.0

# %%
df.isna().sum()
# Out:
# A    0
# B    2
# C    0
# D    3
# dtype: int64

# %%
emp_df = pd.read_csv('Emp_data.csv').head(10)
emp_df
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0  677509       Lois       36.36           60.0           13.68  168251.0
# 1  940761     Brenda         NaN           60.0             NaN   51063.0
# 2  428945        Joe         NaN            NaN             NaN       NaN
# 3  408351      Diane         NaN           51.0           18.30       NaN
# 4  193819   Benjamin       40.31            NaN             NaN  117642.0
# 5  499687    Patrick       34.86           58.0           12.02   72305.0
# 6  539712      Nancy       22.14            NaN            0.87       NaN
# 7  380086      Carol       59.12           40.0           34.52   60918.0
# 8  477616    Frances         NaN           42.0             NaN       NaN
# 9  162402      Diana       29.73           60.0            3.44   43010.0
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# 8         Delmita
# 9  Eureka Springs

# %%
emp_df.isnull().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        4
# Weight in Kgs     3
# Age in Company    4
# Salary            4
# City              0
# dtype: int64

# %%
emp_df.isnull().mean()
# Out:
# Emp ID            0.0
# First Name        0.0
# Age in Yrs        0.4
# Weight in Kgs     0.3
# Age in Company    0.4
# Salary            0.4
# City              0.0
# dtype: float64

# %%
emp_df.isnull().mean() * 100
# Out:
# Emp ID             0.0
# First Name         0.0
# Age in Yrs        40.0
# Weight in Kgs     30.0
# Age in Company    40.0
# Salary            40.0
# City               0.0
# dtype: float64

# %% [markdown]
# ### Handling of Missing Values

# %%
1. drop rows or Columns
2. Imputation Techniques

# %%
emp_df = pd.read_csv('Emp_data.csv').head(12)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 2   428945        Joe         NaN            NaN             NaN       NaN
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87       NaN
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0             NaN       NaN
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.dropna()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 5        Macksburg
# 7      Blanchester
# 9   Eureka Springs
# 11       Las Vegas

# %%
emp_df.dropna(thresh=7)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 5        Macksburg
# 7      Blanchester
# 9   Eureka Springs
# 11       Las Vegas

# %%
emp_df.dropna(thresh=emp_df.shape[1])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 5        Macksburg
# 7      Blanchester
# 9   Eureka Springs
# 11       Las Vegas

# %%
emp_df.dropna(thresh = 6)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 5        Macksburg
# 7      Blanchester
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.dropna(thresh = 5) # 5 Non Null Values
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87       NaN
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.dropna(thresh = 4) # 5 Non Null Values
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87       NaN
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0             NaN       NaN
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.dropna(thresh = 3) # 3 Non Null Values
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 2   428945        Joe         NaN            NaN             NaN       NaN
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87       NaN
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0             NaN       NaN
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.dropna(axis = 0, thresh = 7)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 5        Macksburg
# 7      Blanchester
# 9   Eureka Springs
# 11       Las Vegas

# %%
emp_df.dropna()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 5        Macksburg
# 7      Blanchester
# 9   Eureka Springs
# 11       Las Vegas

# %%
emp_df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        4
# Weight in Kgs     4
# Age in Company    4
# Salary            4
# City              0
# dtype: int64

# %%
emp_df = pd.read_csv('Emp_data.csv').head(12)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 2   428945        Joe         NaN            NaN             NaN       NaN
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        4
# Weight in Kgs     4
# Age in Company    3
# Salary            2
# City              0
# dtype: int64

# %%
emp_df.dropna(axis = 1,thresh=emp_df.shape[0])
# Out:
#     Emp ID First Name            City
# 0   677509       Lois          Denver
# 1   940761     Brenda       Stonewall
# 2   428945        Joe    Michigantown
# 3   408351      Diane        Hydetown
# 4   193819   Benjamin         Fremont
# 5   499687    Patrick       Macksburg
# 6   539712      Nancy         Atlanta
# 7   380086      Carol     Blanchester
# 8   477616    Frances         Delmita
# 9   162402      Diana  Eureka Springs
# 10  231469      Ralph         Sabetha
# 11  153989       Jack       Las Vegas

# %%
emp_df.dropna(axis = 1,thresh=12)
# Out:
#     Emp ID First Name            City
# 0   677509       Lois          Denver
# 1   940761     Brenda       Stonewall
# 2   428945        Joe    Michigantown
# 3   408351      Diane        Hydetown
# 4   193819   Benjamin         Fremont
# 5   499687    Patrick       Macksburg
# 6   539712      Nancy         Atlanta
# 7   380086      Carol     Blanchester
# 8   477616    Frances         Delmita
# 9   162402      Diana  Eureka Springs
# 10  231469      Ralph         Sabetha
# 11  153989       Jack       Las Vegas

# %%
emp_df.dropna(axis = 1,thresh=11)
# Out:
#     Emp ID First Name            City
# 0   677509       Lois          Denver
# 1   940761     Brenda       Stonewall
# 2   428945        Joe    Michigantown
# 3   408351      Diane        Hydetown
# 4   193819   Benjamin         Fremont
# 5   499687    Patrick       Macksburg
# 6   539712      Nancy         Atlanta
# 7   380086      Carol     Blanchester
# 8   477616    Frances         Delmita
# 9   162402      Diana  Eureka Springs
# 10  231469      Ralph         Sabetha
# 11  153989       Jack       Las Vegas

# %%
emp_df.dropna(axis = 1,thresh=10)
# Out:
#     Emp ID First Name    Salary            City
# 0   677509       Lois  168251.0          Denver
# 1   940761     Brenda   51063.0       Stonewall
# 2   428945        Joe       NaN    Michigantown
# 3   408351      Diane       NaN        Hydetown
# 4   193819   Benjamin  117642.0         Fremont
# 5   499687    Patrick   72305.0       Macksburg
# 6   539712      Nancy   72305.0         Atlanta
# 7   380086      Carol   60918.0     Blanchester
# 8   477616    Frances   60918.0         Delmita
# 9   162402      Diana   43010.0  Eureka Springs
# 10  231469      Ralph  118457.0         Sabetha
# 11  153989       Jack   82965.0       Las Vegas

# %%
emp_df.dropna(axis = 1,thresh=9)
# Out:
#     Emp ID First Name  Age in Company    Salary            City
# 0   677509       Lois           13.68  168251.0          Denver
# 1   940761     Brenda             NaN   51063.0       Stonewall
# 2   428945        Joe             NaN       NaN    Michigantown
# 3   408351      Diane           18.30       NaN        Hydetown
# 4   193819   Benjamin             NaN  117642.0         Fremont
# 5   499687    Patrick           12.02   72305.0       Macksburg
# 6   539712      Nancy            0.87   72305.0         Atlanta
# 7   380086      Carol           34.52   60918.0     Blanchester
# 8   477616    Frances           34.52   60918.0         Delmita
# 9   162402      Diana            3.44   43010.0  Eureka Springs
# 10  231469      Ralph            8.29  118457.0         Sabetha
# 11  153989       Jack            0.56   82965.0       Las Vegas

# %%
emp_df.dropna(axis = 1,thresh=emp_df.shape[0] - 3)
# Out:
#     Emp ID First Name  Age in Company    Salary            City
# 0   677509       Lois           13.68  168251.0          Denver
# 1   940761     Brenda             NaN   51063.0       Stonewall
# 2   428945        Joe             NaN       NaN    Michigantown
# 3   408351      Diane           18.30       NaN        Hydetown
# 4   193819   Benjamin             NaN  117642.0         Fremont
# 5   499687    Patrick           12.02   72305.0       Macksburg
# 6   539712      Nancy            0.87   72305.0         Atlanta
# 7   380086      Carol           34.52   60918.0     Blanchester
# 8   477616    Frances           34.52   60918.0         Delmita
# 9   162402      Diana            3.44   43010.0  Eureka Springs
# 10  231469      Ralph            8.29  118457.0         Sabetha
# 11  153989       Jack            0.56   82965.0       Las Vegas

# %% [markdown]
# ### df.drop

# %%
df.drop('ColName', axis = 1)
df.drop(['Col1', 'Col2', ...,'ColN'], axis = 1)
df.drop(['Row1', 'Row2',..., 'RowN'], axis = 0)

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 2   428945        Joe         NaN            NaN             NaN       NaN
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.isna().mean() * 100
# Out:
# Emp ID             0.000000
# First Name         0.000000
# Age in Yrs        33.333333
# Weight in Kgs     33.333333
# Age in Company    25.000000
# Salary            16.666667
# City               0.000000
# dtype: float64

# %%
emp_df.drop('Age in Yrs', axis = 1)
# Out:
#     Emp ID First Name  Weight in Kgs  Age in Company    Salary            City
# 0   677509       Lois           60.0           13.68  168251.0          Denver
# 1   940761     Brenda           60.0             NaN   51063.0       Stonewall
# 2   428945        Joe            NaN             NaN       NaN    Michigantown
# 3   408351      Diane           51.0           18.30       NaN        Hydetown
# 4   193819   Benjamin            NaN             NaN  117642.0         Fremont
# 5   499687    Patrick           58.0           12.02   72305.0       Macksburg
# 6   539712      Nancy            NaN            0.87   72305.0         Atlanta
# 7   380086      Carol           40.0           34.52   60918.0     Blanchester
# 8   477616    Frances           42.0           34.52   60918.0         Delmita
# 9   162402      Diana           60.0            3.44   43010.0  Eureka Springs
# 10  231469      Ralph            NaN            8.29  118457.0         Sabetha
# 11  153989       Jack           61.0            0.56   82965.0       Las Vegas

# %%
emp_df.drop(['Age in Yrs','Weight in Kgs'], axis = 1)
# Out:
#     Emp ID First Name  Age in Company    Salary            City
# 0   677509       Lois           13.68  168251.0          Denver
# 1   940761     Brenda             NaN   51063.0       Stonewall
# 2   428945        Joe             NaN       NaN    Michigantown
# 3   408351      Diane           18.30       NaN        Hydetown
# 4   193819   Benjamin             NaN  117642.0         Fremont
# 5   499687    Patrick           12.02   72305.0       Macksburg
# 6   539712      Nancy            0.87   72305.0         Atlanta
# 7   380086      Carol           34.52   60918.0     Blanchester
# 8   477616    Frances           34.52   60918.0         Delmita
# 9   162402      Diana            3.44   43010.0  Eureka Springs
# 10  231469      Ralph            8.29  118457.0         Sabetha
# 11  153989       Jack            0.56   82965.0       Las Vegas

# %%
emp_df = emp_df.drop(['Emp ID','First Name'], axis = 1)
emp_df
# Out:
#     Age in Yrs  Weight in Kgs  Age in Company    Salary            City
# 0        36.36           60.0           13.68  168251.0          Denver
# 1          NaN           60.0             NaN   51063.0       Stonewall
# 2          NaN            NaN             NaN       NaN    Michigantown
# 3          NaN           51.0           18.30       NaN        Hydetown
# 4        40.31            NaN             NaN  117642.0         Fremont
# 5        34.86           58.0           12.02   72305.0       Macksburg
# 6        22.14            NaN            0.87   72305.0         Atlanta
# 7        59.12           40.0           34.52   60918.0     Blanchester
# 8          NaN           42.0           34.52   60918.0         Delmita
# 9        29.73           60.0            3.44   43010.0  Eureka Springs
# 10       42.50            NaN            8.29  118457.0         Sabetha
# 11       22.21           61.0            0.56   82965.0       Las Vegas

# %%
emp_df
# Out:
#     Age in Yrs  Weight in Kgs  Age in Company    Salary            City
# 0        36.36           60.0           13.68  168251.0          Denver
# 1          NaN           60.0             NaN   51063.0       Stonewall
# 2          NaN            NaN             NaN       NaN    Michigantown
# 3          NaN           51.0           18.30       NaN        Hydetown
# 4        40.31            NaN             NaN  117642.0         Fremont
# 5        34.86           58.0           12.02   72305.0       Macksburg
# 6        22.14            NaN            0.87   72305.0         Atlanta
# 7        59.12           40.0           34.52   60918.0     Blanchester
# 8          NaN           42.0           34.52   60918.0         Delmita
# 9        29.73           60.0            3.44   43010.0  Eureka Springs
# 10       42.50            NaN            8.29  118457.0         Sabetha
# 11       22.21           61.0            0.56   82965.0       Las Vegas

# %%
emp_df = pd.read_csv('Emp_data.csv').head(12)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 2   428945        Joe         NaN            NaN             NaN       NaN
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.drop('Emp ID', axis = 1, inplace=False)
# Out:
#    First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0        Lois       36.36           60.0           13.68  168251.0
# 1      Brenda         NaN           60.0             NaN   51063.0
# 2         Joe         NaN            NaN             NaN       NaN
# 3       Diane         NaN           51.0           18.30       NaN
# 4    Benjamin       40.31            NaN             NaN  117642.0
# 5     Patrick       34.86           58.0           12.02   72305.0
# 6       Nancy       22.14            NaN            0.87   72305.0
# 7       Carol       59.12           40.0           34.52   60918.0
# 8     Frances         NaN           42.0           34.52   60918.0
# 9       Diana       29.73           60.0            3.44   43010.0
# 10      Ralph       42.50            NaN            8.29  118457.0
# 11       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 2   428945        Joe         NaN            NaN             NaN       NaN
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df.drop('Emp ID', axis = 1, inplace=True)

# %%
emp_df.drop([5,7,9])
# Out:
#    First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0        Lois       36.36           60.0           13.68  168251.0
# 1      Brenda         NaN           60.0             NaN   51063.0
# 2         Joe         NaN            NaN             NaN       NaN
# 3       Diane         NaN           51.0           18.30       NaN
# 4    Benjamin       40.31            NaN             NaN  117642.0
# 6       Nancy       22.14            NaN            0.87   72305.0
# 8     Frances         NaN           42.0           34.52   60918.0
# 10      Ralph       42.50            NaN            8.29  118457.0
# 11       Jack       22.21           61.0            0.56   82965.0
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# 6        Atlanta
# 8        Delmita
# 10       Sabetha
# 11     Las Vegas

# %%
emp_df.drop([5,7,9],axis = 0)
# Out:
#    First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0        Lois       36.36           60.0           13.68  168251.0
# 1      Brenda         NaN           60.0             NaN   51063.0
# 2         Joe         NaN            NaN             NaN       NaN
# 3       Diane         NaN           51.0           18.30       NaN
# 4    Benjamin       40.31            NaN             NaN  117642.0
# 6       Nancy       22.14            NaN            0.87   72305.0
# 8     Frances         NaN           42.0           34.52   60918.0
# 10      Ralph       42.50            NaN            8.29  118457.0
# 11       Jack       22.21           61.0            0.56   82965.0
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# 6        Atlanta
# 8        Delmita
# 10       Sabetha
# 11     Las Vegas

# %%
list1 = [3,4,5,6,7]
x = list1.append(100)
print(x)
# Out:
# None

# %%
df2 = emp_df.drop('First Name', axis = 1, inplace=True)
print(df2)
# Out:
# None

# %%
df3 = emp_df.drop('City', axis = 1, inplace=False)
print(df3)
emp_df
# Out:
#     Age in Yrs  Weight in Kgs  Age in Company    Salary
# 0        36.36           60.0           13.68  168251.0
# 1          NaN           60.0             NaN   51063.0
# 2          NaN            NaN             NaN       NaN
# 3          NaN           51.0           18.30       NaN
# 4        40.31            NaN             NaN  117642.0
# 5        34.86           58.0           12.02   72305.0
# 6        22.14            NaN            0.87   72305.0
# 7        59.12           40.0           34.52   60918.0
# 8          NaN           42.0           34.52   60918.0
# 9        29.73           60.0            3.44   43010.0
# 10       42.50            NaN            8.29  118457.0
# 11       22.21           61.0            0.56   82965.0
#     Age in Yrs  Weight in Kgs  Age in Company    Salary            City
# 0        36.36           60.0           13.68  168251.0          Denver
# 1          NaN           60.0             NaN   51063.0       Stonewall
# 2          NaN            NaN             NaN       NaN    Michigantown
# 3          NaN           51.0           18.30       NaN        Hydetown
# 4        40.31            NaN             NaN  117642.0         Fremont
# 5        34.86           58.0           12.02   72305.0       Macksburg
# 6        22.14            NaN            0.87   72305.0         Atlanta
# 7        59.12           40.0           34.52   60918.0     Blanchester
# 8          NaN           42.0           34.52   60918.0         Delmita
# 9        29.73           60.0            3.44   43010.0  Eureka Springs
# 10       42.50            NaN            8.29  118457.0         Sabetha
# 11       22.21           61.0            0.56   82965.0       Las Vegas

# %%
string = 'python'
s1 = string.upper()
print(s1)
# Out:
# PYTHON

# %%
heart_df = pd.read_csv('heart.csv')
heart_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
x = heart_df.drop('target',axis = 1)
y = heart_df['target']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %% [markdown]
# ### Imputation Techniques

# %%
emp_df = pd.read_csv('Emp_data.csv').head(12)
emp_df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        4
# Weight in Kgs     4
# Age in Company    3
# Salary            2
# City              0
# dtype: int64

# %%
emp_df.fillna(1000)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda     1000.00           60.0         1000.00   51063.0
# 2   428945        Joe     1000.00         1000.0         1000.00    1000.0
# 3   408351      Diane     1000.00           51.0           18.30    1000.0
# 4   193819   Benjamin       40.31         1000.0         1000.00  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14         1000.0            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances     1000.00           42.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50         1000.0            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df['Age in Yrs'] = emp_df['Age in Yrs'].fillna(35)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda       35.00           60.0             NaN   51063.0
# 2   428945        Joe       35.00            NaN             NaN       NaN
# 3   408351      Diane       35.00           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances       35.00           42.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df['Weight in Kgs'].fillna(55, inplace=True)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda       35.00           60.0             NaN   51063.0
# 2   428945        Joe       35.00           55.0             NaN       NaN
# 3   408351      Diane       35.00           51.0           18.30       NaN
# 4   193819   Benjamin       40.31           55.0             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14           55.0            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances       35.00           42.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50           55.0            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %% [markdown]
# ### Statistics

# %%
Mean and Median values are used for continuous Data

# %% [markdown]
# ##### Imputation for Continuous Data

# %%
emp_df['Age in Company'].mean()
# Out:
# 14.02222222222222

# %%
emp_df['Age in Company'].median()
# Out:
# 12.02

# %%
np.mean(emp_df['Age in Company'])
# Out:
# 14.02222222222222

# %%
emp_df['Age in Company'].median()
# Out:
# 12.02

# %%
array = np.array([10,14,16,12,17,11,18,19,13])
np.mean(array)
# Out:
# 14.444444444444445

# %%
array = np.array([10,14,16,12,170,11,18,19,13])
np.mean(array)
# Out:
# 31.444444444444443

# %%
array = np.array([10,14,16,12,17,11,18,19,13])
np.median(array)
# Out:
# 14.0

# %%
array = np.array([10,14,16,12,170,11,18,19,13])
np.median(array)
# Out:
# 14.0

# %%
emp_df = pd.read_csv('Emp_data.csv').head(12)
emp_df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        4
# Weight in Kgs     4
# Age in Company    3
# Salary            2
# City              0
# dtype: int64

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 2   428945        Joe         NaN            NaN             NaN       NaN
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0           34.52   60918.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
mean_age = emp_df['Age in Yrs'].mean()
mean_age
# Out:
# 35.903749999999995

# %%
emp_df['Age in Yrs'].fillna(mean_age, inplace=True)

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois    36.36000           60.0           13.68  168251.0
# 1   940761     Brenda    35.90375           60.0             NaN   51063.0
# 2   428945        Joe    35.90375            NaN             NaN       NaN
# 3   408351      Diane    35.90375           51.0           18.30       NaN
# 4   193819   Benjamin    40.31000            NaN             NaN  117642.0
# 5   499687    Patrick    34.86000           58.0           12.02   72305.0
# 6   539712      Nancy    22.14000            NaN            0.87   72305.0
# 7   380086      Carol    59.12000           40.0           34.52   60918.0
# 8   477616    Frances    35.90375           42.0           34.52   60918.0
# 9   162402      Diana    29.73000           60.0            3.44   43010.0
# 10  231469      Ralph    42.50000            NaN            8.29  118457.0
# 11  153989       Jack    22.21000           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
emp_df['Weight in Kgs'].median()
# Out:
# 59.0

# %%
emp_df['Weight in Kgs'].fillna(emp_df['Weight in Kgs'].median(), inplace=True)

# %%
emp_df['Salary'].fillna(emp_df['Salary'].median(), inplace=True)

# %%
emp_df['Age in Company'].fillna(emp_df['Age in Company'].mean(), inplace=True)

# %%
emp_df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     0
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
emp_df = pd.read_csv('Emp_data.csv').head(12)
emp_df['Age in Yrs'].mode()[0]
# Out:
# 22.14

# %%
emp_df['Age in Yrs'].iloc[9] = 59.12
emp_df['Age in Yrs']
# Out:
# <ipython-input-162-1217e9daede8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emp_df['Age in Yrs'].iloc[9] = 59.12
# 0     36.36
# 1       NaN
# 2       NaN
# 3       NaN
# 4     40.31
# 5     34.86
# 6     22.14
# 7     59.12
# 8       NaN
# 9     59.12
# 10    42.50
# 11    22.21
# Name: Age in Yrs, dtype: float64

# %%
emp_df['Age in Yrs'].mode()
# Out:
# 0    59.12
# Name: Age in Yrs, dtype: float64

# %% [markdown]
# ### Imputation for Categorical Data

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           2
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df['Gender'].mode()[0]
# Out:
# 'male'

# %%
titanic_df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic_df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
titanic_df['Embarked'].replace({'S':0,'C':1,'Q':2},inplace = True)

# %%
titanic_df['Embarked'].mean()
# Out:
# 0.36220472440944884

# %%
titanic_df['Embarked'].median()
# Out:
# 0.0

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           2
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df['Embarked'].fillna(titanic_df['Embarked'].mode()[0], inplace=True)

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           2
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
titanic_df['Gender'].fillna(titanic_df['Gender'].mode()[0], inplace=True)

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda         NaN           60.0             NaN   51063.0
# 2   428945        Joe         NaN            NaN             NaN       NaN
# 3   408351      Diane         NaN           51.0           18.30       NaN
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# 5   499687    Patrick       34.86           58.0           12.02   72305.0
# 6   539712      Nancy       22.14            NaN            0.87   72305.0
# 7   380086      Carol       59.12           40.0           34.52   60918.0
# 8   477616    Frances         NaN           42.0           34.52   60918.0
# 9   162402      Diana       59.12           60.0            3.44   43010.0
# 10  231469      Ralph       42.50            NaN            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas

# %%
# Out:
# <ipython-input-188-d5f2009d4508>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   emp_df.std()
# Emp ID            230983.385602
# Age in Yrs            14.198590
# Weight in Kgs          8.635475
# Age in Company        13.047018
# Salary             38753.299000
# dtype: float64

# %%
emp_df['Age in Yrs'].std()
# Out:
# 9.621435290301262

# %%
emp_df['Age in Yrs'].var()
# Out:
# 92.57201704545453

# %%
emp_df['Age in Yrs'].min()
# Out:
# 22.14

# %%
emp_df['Age in Yrs'].max()
# Out:
# 59.12

# %%
emp_df.describe()
# Out:
#               Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count      12.000000   12.000000      12.000000       12.000000      12.000000
# mean   424528.833333   35.903750      55.666667       14.022222   82703.666667
# std    230983.385602    9.621435       7.315405       11.126534   35388.597412
# min    153989.000000   22.140000      40.000000        0.560000   43010.000000
# 25%    222056.500000   33.577500      56.250000        7.077500   60918.000000
# 50%    418648.000000   35.903750      59.000000       13.851111   72305.000000
# 75%    509693.250000   37.347500      60.000000       15.091667   91634.250000
# max    940761.000000   59.120000      61.000000       34.520000  168251.000000
